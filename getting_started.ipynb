# %% [markdown]
# # Your First Chat with AI
#
# Welcome! In this notebook, we'll send a message to Google's **Gemini** AI and see what it says back — just like chatting, but through code.
#
# ### What you'll do
# - Set up everything you need (just a few clicks!)
# - Send a message to the AI
# - Get a response back
#
# ### Before you begin
# - A Google account (you're on Colab, so you have one!)
# - A Gemini API key — think of it as a **password** that lets your code talk to the AI. We'll get one in the next step.
#
# ---

# %% [markdown]
# ## Step 1: Get your API Key
#
# First, let's grab your free API key (the password for talking to the AI):
#
# 1. Go to [Google AI Studio](https://aistudio.google.com/apikey)
# 2. Sign in with your Google account
# 3. You should see a **"Default Gemini API Key"** already created for you — just click the **copy icon** next to it
# 4. If you don't see one, click **"Create API key"** at the top right to generate a new one
#
# ---

# %% [markdown]
# ## Step 2: Save your API Key safely
#
# We'll store your key using Colab's built-in **Secrets** feature so it stays private.
#
# 1. In the left sidebar of this notebook, click the **key icon** (Secrets)
# 2. Click **"Add new secret"**
# 3. Set the **Name** to: `GEMINI_API_KEY`
# 4. Paste your API key as the **Value**
# 5. Toggle the **"Notebook access"** switch to **ON**
#
# > **Why not just paste the key in the code?** If you share this notebook with someone, they'd be able to see and use your key. Secrets keep it hidden.
#
# ---

# %% [markdown]
# ## Step 3: Install what we need
#
# Run the cell below by clicking the **play button** on its left. This downloads the tools our code needs to talk to Gemini. It only takes a few seconds.

# %%
# !pip install -q google-genai

# %% [markdown]
# ## Step 4: Connect to Gemini
#
# Now we'll load your API key and set up a connection to the AI.

# %%
from google.colab import userdata
from google import genai

# Load the API key we saved in Secrets
api_key = userdata.get("GEMINI_API_KEY")

# Set up our connection to Gemini
client = genai.Client(api_key=api_key)

print("Connected! You're ready to chat with the AI.")

# %% [markdown]
# ## Step 5: Send your first message to the AI
#
# Let's ask Gemini a question! This is the core of how AI apps work — you send a message (called a **prompt**), and the AI sends a reply back.

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)

# %% [markdown]
# ### What just happened?
#
# 1. We sent the message `"Explain how AI works in a few words"` to the Gemini AI
# 2. Gemini read our message and came up with a reply
# 3. We printed that reply on screen
#
# That's it — this is the building block of all AI applications!
#
# ---

# %% [markdown]
# ## Step 6: Your turn!
#
# Change the message below to ask Gemini anything you like. Some ideas:
# - `"What is the capital of France?"`
# - `"Write a haiku about programming"`
# - `"Explain gravity to a 10-year-old"`

# %%
# Change this to whatever you want to ask!
my_message = "Write a haiku about programming"

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=my_message,
)

print(response.text)

# %% [markdown]
# ---
#
# ## You did it!
#
# Here's what you just accomplished:
# - Connected to Google's Gemini AI
# - Sent it messages and got replies back
# - Experimented with your own questions
#
# This is the foundation for building AI agents — in the workshop, we'll build on this to create agents that can reason and take actions on their own.
#
# See you at the workshop!
